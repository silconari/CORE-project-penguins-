# %%
from pymongo import MongoClient
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = MongoClient()

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
username= os.getenv("ATLAS_USER")
password= os.getenv("ATLAS_PASSWORD")

# %%
url = f'mongodb+srv://{username}:{password}@cluster0.enltd.mongodb.net/test?authSource=admin&replicaSet=atlas-mrg0dm-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true'

# %%
client = MongoClient(url)

# %%
client
# Out:
# MongoClient(host=['cluster0-shard-00-01.enltd.mongodb.net:27017', 'cluster0-shard-00-02.enltd.mongodb.net:27017', 'cluster0-shard-00-00.enltd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-mrg0dm-shard-0', readpreference='primary', appname='MongoDB Compass', ssl=True)

# %%
db = client.get_database("penguins-data")
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.enltd.mongodb.net:27017', 'cluster0-shard-00-02.enltd.mongodb.net:27017', 'cluster0-shard-00-00.enltd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-mrg0dm-shard-0', readpreference='primary', appname='MongoDB Compass', ssl=True), 'penguins-data')

# %%
penguins = db.penguins

list(penguins.find({}))
# Out:
# [{'_id': ObjectId('6107a17cd1ab47e0074f76ae'),
#   '': '0',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Island': 'Torgersen',
#   'Individual ID': 'N1A1',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '11/11/2007',
#   'Culmen Length (mm)': '39.1',
#   'Culmen Depth (mm)': '18.7',
#   'Flipper Length (mm)': '181.0',
#   'Body Mass (g)': '3750.0',
#   'Sex': 'MALE'},
#  {'_id': ObjectId('6107a17cd1ab47e0074f76af'),
#   '': '1',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Island': 'Torgersen',
#   'Individual ID': 'N1A2',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '11/11/2007',
#   'Culmen Length (mm)': '39.5',
#   'Culmen Depth (mm)': '17.4',
#   'Flipper Length (mm)': '186.0',
#   'Body Mass (g)': '3800.0',
#   'Sex': 'FEMALE'},
#  {'_id': ObjectId('6107a17cd1ab47e0074f76b0'),
#   '': '2',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Island': 'Torgersen',
#   'Individual ID': 'N2A1',
#   'Clutch Completion': 'Yes',
# ...

# %%
len(list(db.penguins.find({"Sex": "FEMALE"})))
# Out:
# 165

# %%
len(list(db.penguins.find({"Sex": "MALE"})))
# Out:
# 168
