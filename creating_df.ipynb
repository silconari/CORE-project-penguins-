# %%
import pandas as pd

# %%
df = pd.read_csv('./new_db.csv')

# %%
df.shape
# Out:
# (344, 11)

# %%
df.head()
# Out:
#    Unnamed: 0                              Species     Island Individual ID  \
# 0           0  Adelie Penguin (Pygoscelis adeliae)  Torgersen          N1A1
# 1           1  Adelie Penguin (Pygoscelis adeliae)  Torgersen          N1A2
# 2           2  Adelie Penguin (Pygoscelis adeliae)  Torgersen          N2A1
# 3           3  Adelie Penguin (Pygoscelis adeliae)  Torgersen          N2A2
# 4           4  Adelie Penguin (Pygoscelis adeliae)  Torgersen          N3A1
#
#   Clutch Completion    Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0               Yes  11/11/2007                39.1               18.7
# 1               Yes  11/11/2007                39.5               17.4
# 2               Yes    11/16/07                40.3               18.0
# 3               Yes    11/16/07                 NaN                NaN
# 4               Yes    11/16/07                36.7               19.3
#
#    Flipper Length (mm)  Body Mass (g)     Sex
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# Species                 0
# Island                  0
# Individual ID           0
# Clutch Completion       0
# Date Egg                0
# Culmen Length (mm)      2
# Culmen Depth (mm)       2
# Flipper Length (mm)     2
# Body Mass (g)           2
# Sex                    10
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# count  344.000000          342.000000         342.000000           342.000000
# mean   171.500000           43.921930          17.151170           200.915205
# std     99.448479            5.459584           1.974793            14.061714
# min      0.000000           32.100000          13.100000           172.000000
# 25%     85.750000           39.225000          15.600000           190.000000
# 50%    171.500000           44.450000          17.300000           197.000000
# 75%    257.250000           48.500000          18.700000           213.000000
# max    343.000000           59.600000          21.500000           231.000000
#
#        Body Mass (g)
# count     342.000000
# mean     4201.754386
# std       801.954536
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4750.000000
# max      6300.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Species', 'Island', 'Individual ID', 'Clutch Completion',
#        'Date Egg', 'Culmen Length (mm)', 'Culmen Depth (mm)',
#        'Flipper Length (mm)', 'Body Mass (g)', 'Sex'],
#       dtype='object')

# %%
df.drop(df.columns[0], axis = 1)
# Out:
#                                  Species     Island Individual ID  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Torgersen          N1A1
# 1    Adelie Penguin (Pygoscelis adeliae)  Torgersen          N1A2
# 2    Adelie Penguin (Pygoscelis adeliae)  Torgersen          N2A1
# 3    Adelie Penguin (Pygoscelis adeliae)  Torgersen          N2A2
# 4    Adelie Penguin (Pygoscelis adeliae)  Torgersen          N3A1
# ..                                   ...        ...           ...
# 339    Gentoo penguin (Pygoscelis papua)     Biscoe         N38A2
# 340    Gentoo penguin (Pygoscelis papua)     Biscoe         N39A1
# 341    Gentoo penguin (Pygoscelis papua)     Biscoe         N39A2
# 342    Gentoo penguin (Pygoscelis papua)     Biscoe         N43A1
# 343    Gentoo penguin (Pygoscelis papua)     Biscoe         N43A2
#
#     Clutch Completion    Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0                 Yes  11/11/2007                39.1               18.7
# ...
